# %% [markdown]
# # Import library

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math
import matplotlib.pyplot as plt
import joblib
import os
import pickle
# Out:
# 2024-12-15 03:11:52.220928: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-15 03:11:52.226405: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-15 03:11:52.242089: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1734232312.266325 2352962 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1734232312.273651 2352962 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # Preprocesssing data

# %% [markdown]
# ## Read data to dataframe

# %%
output_file_path_final = 'service_metrics_uptodate.xlsx'
df = pd.read_excel(output_file_path_final)

# %%
print(df.head())
# Out:
#            Service Label  Total CPU (m)  Total Memory (Mi)  Pod Count  \
# 0           emailservice              3                 55          1
# 1        checkoutservice              5                 16          1
# 2  recommendationservice             22                 59          1
# 3               frontend             60                 37          2
# 4         paymentservice              2                 48          1
#
#       Timestamp
# 0  1.733722e+09
# 1  1.733722e+09
# 2  1.733722e+09
# 3  1.733722e+09
# 4  1.733722e+09

# %% [markdown]
# ## Label and create lookback

# %%
# Mapping Service Label -> Label
service_mapping = {
    "emailservice": 1,
    "checkoutservice": 2,
    "recommendationservice": 3,
    "frontend": 4,
    "paymentservice": 5,
    "productcatalogservice": 6,
    "cartservice": 7,
    "redis-cart": 8,
    "currencyservice": 9,
    "shippingservice": 10,
    "adservice": 11,
}

# Attach label
df['Service Label Number'] = df['Service Label'].map(service_mapping)

def prepare_dataframe(df, n_steps):
    dataframes = []
    # group by label
    for label, group in df.groupby('Service Label Number'):
        # group by timestamp
        group = group.sort_values('Timestamp')
        group.set_index('Timestamp', inplace=True)

        # Create lockback cols
        for i in range(1, n_steps + 1):
            group[f'Close(t-{i})'] = group['Total CPU (m)'].shift(i)

        # delete NaN value by shift
        group.dropna(inplace=True)
        dataframes.append(group)

    return pd.concat(dataframes)

# Set loockback value
lookback = 5
shifted_df = prepare_dataframe(df, lookback)

# %% [markdown]
# ## Save data to new_file

# %%
# List required cols
required_columns = ['Timestamp', 'Service Label Number', 'Total CPU (m)', 'Close(t-1)', 'Close(t-2)', 'Close(t-3)', 'Close(t-4)', 'Close(t-5)', 'Pod Count']

# Get cols form DataFrame
final_df = shifted_df.reset_index()[required_columns]

# Change name of cols
final_df.columns = ['Timestamp', 'Label', 'CPU(t)', 'CPU(t-1)', 'CPU(t-2)', 'CPU(t-3)', 'CPU(t-4)', 'CPU(t-5)', 'Current Pods']

# Save file to xlsx
df_sorted = final_df.sort_values(by='Timestamp', ascending=True).reset_index(drop=True)
output_file_path_final = 'final_service_metrics_demo.xlsx'
df_sorted.to_excel(output_file_path_final, index=False)

# %% [markdown]
# ## Read new data to new dataframe

# %%
new_df = pd.read_excel(output_file_path_final)
new_df
# Out:
#           Timestamp  Label  CPU(t)  CPU(t-1)  CPU(t-2)  CPU(t-3)  CPU(t-4)  \
# 0      1.733722e+09      1       3         4         3         4         4
# 1      1.733722e+09      2       3         7         2         4         6
# 2      1.733722e+09      3      22        25        19        21        24
# 3      1.733722e+09      4      59        60        59        51        51
# 4      1.733722e+09      5       1         2         1         2         2
# ...             ...    ...     ...       ...       ...       ...       ...
# 75532  1.734196e+09      7      12        15        17        16        24
# 75533  1.734196e+09      8      17        16        17        17        17
# 75534  1.734196e+09      9      13        15        20        14        15
# 75535  1.734196e+09     10       4         4         5         4         4
# 75536  1.734196e+09     11       4         4         3         4         4
#
#        CPU(t-5)  Current Pods
# 0             3             1
# ...

# %% [markdown]
# ## Feature/Target and splitdata

# %%
new_df.set_index(['Timestamp', 'Label'], inplace=True)

# X and y
X = new_df[['CPU(t-1)', 'CPU(t-2)', 'CPU(t-3)', 'CPU(t-4)', 'CPU(t-5)']]
y = new_df['CPU(t)']

# split train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Standardize data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
joblib.dump(scaler, 'data_scaler.pkl')
# Out:
# ['data_scaler.pkl']

# %% [markdown]
# # Define and train model

# %%
# Build model
model_ann = Sequential([
    Dense(128, input_dim=X_train.shape[1], activation='relu'),
    Dense(64, activation='relu'),
    Dense(1)
])

# Compile model
model_ann.compile(optimizer=Adam(learning_rate=0.01), loss='mse', metrics=['mae'])

# Train model
history_ann = model_ann.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
loss, mae = model_ann.evaluate(X_test, y_test)
print('loss : ' + loss)
print('mae : ' + mae)
# Out:
# Epoch 1/50
# /root/miniconda3/envs/carbon_model/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-12-15 03:14:07.371561: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1674.9510 - mae: 11.6339 - val_loss: 226.6587 - val_mae: 5.0031
# Epoch 2/50
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 232.3466 - mae: 5.8578 - val_loss: 233.6612 - val_mae: 5.3314
# Epoch 3/50
# 1511/1511 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 233.5721 - mae: 5.8281 - val_loss: 237.5711 - val_mae: 5.3715
# Epoch 4/50
# ...

# %%
print(loss)
print(mae)
# Out:
# 207.9451446533203
# 5.423585891723633

# %%
model_ann.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,269 (106.52 KB)
#  Trainable params: 9,089 (35.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 18,180 (71.02 KB)

# %%
biases = [layer.get_weights()[1] for layer in model_ann.layers]
print("Hệ số bias bù từ các lớp:", biases)
# Out:
# Hệ số bias bù từ các lớp: [array([ 3.2458787 , -0.5203014 , -1.2158796 , -0.859881  , -2.9616344 ,
#        -0.37437215, -0.22932309, -0.8783998 , -0.14602037,  1.2300087 ,
#        -4.2983017 , -0.4863502 , -0.16770476, -0.3788221 , -0.39440674,
#         0.08935867, -0.23651949, -1.8315862 , -0.24142297, -0.4072842 ,
#        -0.54795957, -0.724339  , -0.34843507, -0.62702215, -0.6208032 ,
#        -2.9183898 , -1.5402958 , -0.604669  , -1.8450613 , -0.5062625 ,
#        -0.5709053 , -0.36861327, -1.5494118 ,  1.1017221 , -2.4703526 ,
#        -0.95019454, -0.5690291 , -0.7959877 , -0.4307541 , -0.1756863 ,
#        -0.59545404, -0.78620404, -0.33568186, -2.3278797 , -0.23076862,
#        -0.5123457 , -0.4320213 , -0.5011634 , -0.2910349 , -0.44257015,
#        -0.9947892 , -0.6077231 , -0.32009646, -0.49203676, -2.4938352 ,
#        -1.2601401 , -0.9591011 , -0.4233677 ,  2.7692804 , -0.32124186,
#        -0.19570819, -0.38317564, -0.37806273, -0.17625971, -0.34048268,
# ...

# %% [markdown]
# # Evaluate

# %%
y_pred_ann = model_ann.predict(X_test)

mae_ann = mean_absolute_error(y_test, y_pred_ann)
mse_ann = mean_squared_error(y_test, y_pred_ann)
rmse_ann = math.sqrt(mse_ann)

print(f"RNN - MAE: {mae_ann}")
print(f"RNN - MSE: {mse_ann}")
print(f"RNN - RMSE: {rmse_ann}")
# Out:
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 1s 984us/step
# RNN - MAE: 5.423585963116647
# RNN - MSE: 207.94514430381818
# RNN - RMSE: 14.42030319736094

# %% [markdown]
# # Visualize

# %%
# Plot Actual vs Predicted (ANN)
plt.figure(figsize=(12, 6))
plt.plot(y_test.values[:200], label='Actual', color='blue')
plt.plot(y_pred_ann[:200], label='ANN Predicted', linestyle='--', color='orange')
plt.title('Actual vs ANN Predict')
plt.xlabel('Sample')
plt.ylabel('CPU usage')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Convert timestamp to timedate and merge actual + predict

# %%
y_pred_ann_flat = [x[0] for x in y_pred_ann]

df_compare_pred = pd.DataFrame({
    'Timestamp': y_test.index.get_level_values('Timestamp'),
    'Label': y_test.index.get_level_values('Label'),
    'Actual': y_test.values,
    'Predicted': y_pred_ann_flat                             
})

df_compare_pred
# Out:
#           Timestamp  Label  Actual   Predicted
# 0      1.734094e+09      7     187  194.483902
# 1      1.734094e+09      8      33   33.377769
# 2      1.734094e+09      9     181  193.881332
# 3      1.734094e+09     10      36   38.948669
# 4      1.734094e+09     11      27   27.776592
# ...             ...    ...     ...         ...
# 15103  1.734196e+09      7      12   17.656013
# 15104  1.734196e+09      8      17   16.867117
# 15105  1.734196e+09      9      13   16.811914
# 15106  1.734196e+09     10       4    5.661688
# 15107  1.734196e+09     11       4    5.091436
#
# [15108 rows x 4 columns]

# %%
df_compare_pred['TimeDate'] = pd.to_datetime(df_compare_pred['Timestamp'], unit='s')

min_timestamp = df_compare_pred['TimeDate'].min()
max_timestamp = df_compare_pred['TimeDate'].max()

print(f"Range of Timestamp: {min_timestamp} to {max_timestamp}")
# Out:
# Range of Timestamp: 2024-12-13 12:43:14.704502106 to 2024-12-14 17:13:23.780251026

# %%
start_time_visualize = pd.Timestamp('2024-12-13 00:00:01')
end_time_visualize = pd.Timestamp('2024-12-13 23:59:59')

# filter by time
df_filtered = df_compare_pred[(df_compare_pred['TimeDate'] >= start_time_visualize) & (df_compare_pred['TimeDate'] <= end_time_visualize)]

unique_labels = df_filtered['Label'].unique()

for label in unique_labels:
    
    df_label = df_filtered[df_filtered['Label'] == label]
    
    plt.figure(figsize=(10, 6))
    plt.plot(df_label['TimeDate'], df_label['Actual'], label='Actual', color='blue', marker='o')
    plt.plot(df_label['TimeDate'], df_label['Predicted'], label='Predict', color='orange', linestyle='--', marker='x')
    plt.title(f'Label: {label} - Thực tế vs Dự đoán', fontsize=22)
    plt.xlabel('Time', fontsize=18)
    plt.ylabel('CPU usage', fontsize=18)
    plt.legend()
    plt.grid()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Predict time in feature

# %%
new_input_df = new_df.tail(1000)
new_input_df = new_input_df.reset_index()

new_input_df['TimeDate'] = pd.to_datetime(new_input_df['Timestamp'], unit= 's')

# Range of Timestamp new_input_df
min_timestamp = new_input_df['TimeDate'].min()
max_timestamp = new_input_df['TimeDate'].max()

print(f"Range of Timestamp: {min_timestamp} to {max_timestamp}")
# Out:
# Range of Timestamp: 2024-12-14 15:19:14.375017881 to 2024-12-14 17:13:23.780251026

# %% [markdown]
# ## Predict at 18:15

# %%
last_timestamp = max_timestamp
predict_timestamp = pd.Timestamp('2024-12-14 18:15:00')

last_metrics = new_input_df[new_input_df['TimeDate'] <= last_timestamp].groupby('Label').tail(1)

print(last_metrics)
# Out:
#         Timestamp  Label  CPU(t)  CPU(t-1)  CPU(t-2)  CPU(t-3)  CPU(t-4)  \
# 989  1.734196e+09      1       4         3         4         3         3
# 990  1.734196e+09      2       4         3         2         3         4
# 991  1.734196e+09      3      10        10         9         9         9
# 992  1.734196e+09      4      79        84        88        86        82
# 993  1.734196e+09      5       2         1         2         2         1
# 994  1.734196e+09      6      15        14        14        13        12
# 995  1.734196e+09      7      12        15        17        16        24
# 996  1.734196e+09      8      17        16        17        17        17
# 997  1.734196e+09      9      13        15        20        14        15
# 998  1.734196e+09     10       4         4         5         4         4
# 999  1.734196e+09     11       4         4         3         4         4
#
#      CPU(t-5)  Current Pods                      TimeDate
# ...

# %%
future_timestamps = []
predictions = []

while last_timestamp < predict_timestamp:

    last_timestamp += pd.Timedelta(minutes=1)
    future_timestamps.append(last_timestamp)

    predicted_row = []

    # Predict for each label
    for label in last_metrics['Label'].unique():
        # get data from last metric
        service_data = last_metrics[last_metrics['Label'] == label][['CPU(t-1)', 'CPU(t-2)', 'CPU(t-3)', 'CPU(t-4)', 'CPU(t-5)']].iloc[0].values
        service_data = service_data.reshape(1, -1)
        
        service_data_scaled = scaler.transform(service_data)  # scaler

        prediction = model_ann.predict(service_data_scaled) 
        
        predicted_row.append({
            'Label': label,
            'CPU(t)': prediction
        })

        # update history value
        last_metrics.loc[last_metrics['Label'] == label, 'CPU(t-5)'] = last_metrics.loc[last_metrics['Label'] == label, 'CPU(t-4)']
        last_metrics.loc[last_metrics['Label'] == label, 'CPU(t-4)'] = last_metrics.loc[last_metrics['Label'] == label, 'CPU(t-3)']
        last_metrics.loc[last_metrics['Label'] == label, 'CPU(t-3)'] = last_metrics.loc[last_metrics['Label'] == label, 'CPU(t-2)']
        last_metrics.loc[last_metrics['Label'] == label, 'CPU(t-2)'] = last_metrics.loc[last_metrics['Label'] == label, 'CPU(t-1)']
        last_metrics.loc[last_metrics['Label'] == label, 'CPU(t-1)'] = prediction  

    # Save all predict
    predictions.extend([{
        'Timestamp': last_timestamp,
        'Label': row['Label'],
        'CPU(t)': row['CPU(t)']
    } for row in predicted_row])

result_df = pd.DataFrame(predictions)

print(result_df)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# /root/miniconda3/envs/carbon_model/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /tmp/ipykernel_2352962/3996015388.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.8871346]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   last_metrics.loc[last_metrics['Label'] == label, 'CPU(t-1)'] = prediction
# /root/miniconda3/envs/carbon_model/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(20, 8))
unique_labels = result_df['Label'].unique()


for label in unique_labels:
    label_data = result_df[result_df['Label'] == label]
    plt.plot(label_data['Timestamp'], label_data['CPU(t)'], marker='o', label=f'Dịch vụ {label}')

plt.title('Predict CPU usage for all service', fontsize=30)
plt.xlabel('Time',fontsize=22)
plt.ylabel('Total CPU (m)', fontsize=22)
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
